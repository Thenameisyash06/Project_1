# %% [markdown]
# # Importing and Loading Datasets

# %%
import pandas as pd
df = pd.read_csv("train[1].csv")
df
bf = pd.read_csv("test[1].csv")
bf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Feature Engineering
#
# # Finding Correlation between features and target

# %%
correlation_matrix = df.corr()

target_corr = correlation_matrix['SalePrice'].sort_values(ascending=False)
print(target_corr)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# # Dropping the Numeric features which is less relevant

# %%
df = df.drop(['KitchenAbvGr','EnclosedPorch','MSSubClass','OverallCond','YrSold','LowQualFinSF','Id','MiscVal','BsmtHalfBath','BsmtFinSF2','3SsnPorch','MoSold','PoolArea'],axis='columns')
bf = bf.drop(['KitchenAbvGr','EnclosedPorch','MSSubClass','OverallCond','YrSold','LowQualFinSF','Id','MiscVal','BsmtHalfBath','BsmtFinSF2','3SsnPorch','MoSold','PoolArea'],axis='columns')

# %%
df
# Out:
#      MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0          RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1          RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2          RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3          RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4          RL         84.0    14260   Pave   NaN      IR1         Lvl
# ...       ...          ...      ...    ...   ...      ...         ...
# 1455       RL         62.0     7917   Pave   NaN      Reg         Lvl
# 1456       RL         85.0    13175   Pave   NaN      Reg         Lvl
# 1457       RL         66.0     9042   Pave   NaN      Reg         Lvl
# 1458       RL         68.0     9717   Pave   NaN      Reg         Lvl
# 1459       RL         75.0     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... PavedDrive WoodDeckSF OpenPorchSF  \
# ...

# %%
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'ScreenPorch', 'PoolQC', 'Fence',
# ...

# %% [markdown]
# # Evaluating relevancy of Non-Numeric features using chi-square test

# %%
from scipy.stats import chi2_contingency
non_numeric_columns = df.select_dtypes(include=['object']).columns

# Evaluate relevance using chi-square test
for column in non_numeric_columns:
    contingency_table = pd.crosstab(df[column], df['SalePrice'])
    chi2, p_value,_,_= chi2_contingency(contingency_table)
    print(f"Feature: {column}, Chi-square: {chi2}, p-value: {p_value}")
# Out:
# Feature: MSZoning, Chi-square: 3147.8911158183737, p-value: 4.3483250606822396e-11
# Feature: Street, Chi-square: 888.3129945096931, p-value: 8.338870380464053e-09
# Feature: Alley, Chi-square: 91.00000000000001, p-value: 0.20972415885759163
# Feature: LotShape, Chi-square: 2446.2353573800365, p-value: 4.724729155980402e-12
# Feature: LandContour, Chi-square: 2072.335508433759, p-value: 0.08674645041917711
# Feature: Utilities, Chi-square: 242.49942883253368, p-value: 1.0
# Feature: LotConfig, Chi-square: 2771.9854545078742, p-value: 0.045806211958033756
# Feature: LandSlope, Chi-square: 1388.847891459522, p-value: 0.10508638737793884
# Feature: Neighborhood, Chi-square: 16898.75578956907, p-value: 1.364960102688296e-08
# Feature: Condition1, Chi-square: 4147.618513410399, p-value: 1.0
# Feature: Condition2, Chi-square: 4772.610202894631, p-value: 0.07598640644469955
# Feature: BldgType, Chi-square: 2354.0254509759116, p-value: 0.9999860714473023
# ...

# %% [markdown]
# # Dropping Non-Numeric features which is less relevant

# %%
#utilites, condition2, RoofMatl, alley, LandSlope, Condition1, BldgType, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, BsmtFinType1, BsmtFinType2, HeatingQC, Functional, GarageType, GarageCond, PavedDrive, PoolQC, MiscFeature, 
df = df.drop(['Utilities','Alley','Condition2','RoofMatl', 'LandSlope', 'Condition1', 'BldgType', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'Functional', 'GarageType', 'GarageCond', 'PavedDrive', 'PoolQC', 'MiscFeature'],axis='columns')
bf = bf.drop(['Utilities','Alley','Condition2','RoofMatl', 'LandSlope', 'Condition1', 'BldgType', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'Functional', 'GarageType', 'GarageCond', 'PavedDrive', 'PoolQC', 'MiscFeature'],axis='columns')
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'LotConfig', 'Neighborhood', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'WoodDeckSF', 'OpenPorchSF',
#        'ScreenPorch', 'Fence', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'LotConfig',
#        'Neighborhood', 'HouseStyle', 'MasVnrType', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'Heating',
#        'CentralAir', 'Electrical', 'KitchenQual', 'FireplaceQu',
#        'GarageFinish', 'GarageQual', 'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # Doing Label Encoding to convert Non-numeric features to Numeric features

# %%
# Sex_n = LabelEncoder()
# df['Sex_n'] = Sex_n.fit_transform(df['Sex'])
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['MSZoning_n'] = le.fit_transform(df['MSZoning'])
df['Street_n'] = le.fit_transform(df['Street'])
df['LotShape_n'] = le.fit_transform(df['LotShape'])
df['LandContour_n'] = le.fit_transform(df['LandContour'])
df['LotConfig_n'] = le.fit_transform(df['LotConfig'])
df['Neighborhood_n'] = le.fit_transform(df['Neighborhood'])
df['HouseStyle_n'] = le.fit_transform(df['HouseStyle'])
df['MasVnrType_n'] = le.fit_transform(df['MasVnrType'])
df['ExterQual_n'] = le.fit_transform(df['ExterQual'])
df['ExterCond_n'] = le.fit_transform(df['ExterCond'])
df['Foundation_n'] = le.fit_transform(df['Foundation'])
df['BsmtQual_n'] = le.fit_transform(df['BsmtQual'])
df['BsmtCond_n'] = le.fit_transform(df['BsmtCond'])
df['BsmtExposure_n'] = le.fit_transform(df['BsmtExposure'])
df['Heating_n'] = le.fit_transform(df['Heating'])
df['CentralAir_n'] = le.fit_transform(df['CentralAir'])
df['Electrical_n'] = le.fit_transform(df['Electrical'])
df['KitchenQual_n'] = le.fit_transform(df['KitchenQual'])
df['FireplaceQu_n'] = le.fit_transform(df['FireplaceQu'])
df['GarageFinish_n'] = le.fit_transform(df['GarageFinish'])
df['GarageQual_n'] = le.fit_transform(df['GarageQual'])
df['Fence_n'] = le.fit_transform(df['Fence'])
df['SaleType_n'] = le.fit_transform(df['SaleType'])
df['SaleCondition_n'] = le.fit_transform(df['SaleCondition'])
df
# Out:
#      MSZoning  LotFrontage  LotArea Street LotShape LandContour LotConfig  \
# 0          RL         65.0     8450   Pave      Reg         Lvl    Inside
# 1          RL         80.0     9600   Pave      Reg         Lvl       FR2
# 2          RL         68.0    11250   Pave      IR1         Lvl    Inside
# 3          RL         60.0     9550   Pave      IR1         Lvl    Corner
# 4          RL         84.0    14260   Pave      IR1         Lvl       FR2
# ...       ...          ...      ...    ...      ...         ...       ...
# 1455       RL         62.0     7917   Pave      Reg         Lvl    Inside
# 1456       RL         85.0    13175   Pave      Reg         Lvl    Inside
# 1457       RL         66.0     9042   Pave      Reg         Lvl    Inside
# 1458       RL         68.0     9717   Pave      Reg         Lvl    Inside
# 1459       RL         75.0     9937   Pave      Reg         Lvl    Inside
#
#      Neighborhood HouseStyle  OverallQual  ...  Heating_n  CentralAir_n  \
# ...

# %%
bf['MSZoning_n'] = le.fit_transform(bf['MSZoning'])
bf['Street_n'] = le.fit_transform(bf['Street'])
bf['LotShape_n'] = le.fit_transform(bf['LotShape'])
bf['LandContour_n'] = le.fit_transform(bf['LandContour'])
bf['LotConfig_n'] = le.fit_transform(bf['LotConfig'])
bf['Neighborhood_n'] = le.fit_transform(bf['Neighborhood'])
bf['HouseStyle_n'] = le.fit_transform(bf['HouseStyle'])
bf['MasVnrType_n'] = le.fit_transform(bf['MasVnrType'])
bf['ExterQual_n'] = le.fit_transform(bf['ExterQual'])
bf['ExterCond_n'] = le.fit_transform(bf['ExterCond'])
bf['Foundation_n'] = le.fit_transform(bf['Foundation'])
bf['BsmtQual_n'] = le.fit_transform(bf['BsmtQual'])
bf['BsmtCond_n'] = le.fit_transform(bf['BsmtCond'])
bf['BsmtExposure_n'] = le.fit_transform(bf['BsmtExposure'])
bf['Heating_n'] = le.fit_transform(bf['Heating'])
bf['CentralAir_n'] = le.fit_transform(bf['CentralAir'])
bf['Electrical_n'] = le.fit_transform(bf['Electrical'])
bf['KitchenQual_n'] = le.fit_transform(bf['KitchenQual'])
bf['FireplaceQu_n'] = le.fit_transform(bf['FireplaceQu'])
bf['GarageFinish_n'] = le.fit_transform(bf['GarageFinish'])
bf['GarageQual_n'] = le.fit_transform(bf['GarageQual'])
bf['Fence_n'] = le.fit_transform(bf['Fence'])
bf['SaleType_n'] = le.fit_transform(bf['SaleType'])
bf['SaleCondition_n'] = le.fit_transform(bf['SaleCondition'])
bf
# Out:
#      MSZoning  LotFrontage  LotArea Street LotShape LandContour LotConfig  \
# 0          RH         80.0    11622   Pave      Reg         Lvl    Inside
# 1          RL         81.0    14267   Pave      IR1         Lvl    Corner
# 2          RL         74.0    13830   Pave      IR1         Lvl    Inside
# 3          RL         78.0     9978   Pave      IR1         Lvl    Inside
# 4          RL         43.0     5005   Pave      IR1         HLS    Inside
# ...       ...          ...      ...    ...      ...         ...       ...
# 1454       RM         21.0     1936   Pave      Reg         Lvl    Inside
# 1455       RM         21.0     1894   Pave      Reg         Lvl    Inside
# 1456       RL        160.0    20000   Pave      Reg         Lvl    Inside
# 1457       RL         62.0    10441   Pave      Reg         Lvl    Inside
# 1458       RL         74.0     9627   Pave      Reg         Lvl    Inside
#
#      Neighborhood HouseStyle  OverallQual  ...  Heating_n  CentralAir_n  \
# ...

# %%
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'LotConfig', 'Neighborhood', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'WoodDeckSF', 'OpenPorchSF',
#        'ScreenPorch', 'Fence', 'SaleType', 'SaleCondition', 'SalePrice',
#        'MSZoning_n', 'Street_n', 'LotShape_n', 'LandContour_n', 'LotConfig_n',
#        'Neighborhood_n', 'HouseStyle_n', 'MasVnrType_n', 'ExterQual_n',
#        'ExterCond_n', 'Foundation_n', 'BsmtQual_n', 'BsmtCond_n',
# ...

# %% [markdown]
# # Dropping duplicate columns

# %%
df = df.drop(['MSZoning','Street','LotShape','LandContour','LotConfig','Neighborhood','HouseStyle','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','Heating','CentralAir','Electrical','KitchenQual','FireplaceQu','GarageFinish','GarageQual','Fence','SaleType','SaleCondition'],axis='columns')
bf = bf.drop(['MSZoning','Street','LotShape','LandContour','LotConfig','Neighborhood','HouseStyle','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','Heating','CentralAir','Electrical','KitchenQual','FireplaceQu','GarageFinish','GarageQual','Fence','SaleType','SaleCondition'],axis='columns')
df
# Out:
#       LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0            65.0     8450            7       2003          2003       196.0
# 1            80.0     9600            6       1976          1976         0.0
# 2            68.0    11250            7       2001          2002       162.0
# 3            60.0     9550            7       1915          1970         0.0
# 4            84.0    14260            8       2000          2000       350.0
# ...           ...      ...          ...        ...           ...         ...
# 1455         62.0     7917            6       1999          2000         0.0
# 1456         85.0    13175            6       1978          1988       119.0
# 1457         66.0     9042            7       1941          2006         0.0
# 1458         68.0     9717            5       1950          1996         0.0
# 1459         75.0     9937            5       1965          1965         0.0
#
# ...

# %% [markdown]
# # Handling missing values

# %%
nan_values = df.isnull().any()
nan_values
# Out:
# LotFrontage         True
# LotArea            False
# OverallQual        False
# YearBuilt          False
# YearRemodAdd       False
# MasVnrArea          True
# BsmtFinSF1         False
# BsmtUnfSF          False
# TotalBsmtSF        False
# 1stFlrSF           False
# 2ndFlrSF           False
# GrLivArea          False
# BsmtFullBath       False
# FullBath           False
# HalfBath           False
# BedroomAbvGr       False
# TotRmsAbvGrd       False
# Fireplaces         False
# GarageYrBlt         True
# GarageCars         False
# GarageArea         False
# WoodDeckSF         False
# OpenPorchSF        False
# ScreenPorch        False
# SalePrice          False
# MSZoning_n         False
# Street_n           False
# LotShape_n         False
# LandContour_n      False
# LotConfig_n        False
# Neighborhood_n     False
# HouseStyle_n       False
# MasVnrType_n       False
# ExterQual_n        False
# ExterCond_n        False
# Foundation_n       False
# BsmtQual_n         False
# ...

# %%
df.LotFrontage = df.LotFrontage.fillna(0)
df = df.dropna(subset=['MasVnrArea'])
median_value = df['GarageYrBlt'].median()
df.GarageYrBlt = df.GarageYrBlt.fillna(median_value)
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_19744\3112429057.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.GarageYrBlt = df.GarageYrBlt.fillna(median_value)

# %%
nan_values = df.isnull().any()
nan_values
# Out:
# LotFrontage        False
# LotArea            False
# OverallQual        False
# YearBuilt          False
# YearRemodAdd       False
# MasVnrArea         False
# BsmtFinSF1         False
# BsmtUnfSF          False
# TotalBsmtSF        False
# 1stFlrSF           False
# 2ndFlrSF           False
# GrLivArea          False
# BsmtFullBath       False
# FullBath           False
# HalfBath           False
# BedroomAbvGr       False
# TotRmsAbvGrd       False
# Fireplaces         False
# GarageYrBlt        False
# GarageCars         False
# GarageArea         False
# WoodDeckSF         False
# OpenPorchSF        False
# ScreenPorch        False
# SalePrice          False
# MSZoning_n         False
# Street_n           False
# LotShape_n         False
# LandContour_n      False
# LotConfig_n        False
# Neighborhood_n     False
# HouseStyle_n       False
# MasVnrType_n       False
# ExterQual_n        False
# ExterCond_n        False
# Foundation_n       False
# BsmtQual_n         False
# ...

# %%
bf.LotFrontage = bf.LotFrontage.fillna(0)
bf = bf.dropna(subset=['MasVnrArea'])
median_value = bf['GarageYrBlt'].median()
bf.GarageYrBlt = bf.GarageYrBlt.fillna(median_value) #ignore: Warnings

# %%
bf = bf.dropna(subset=['BsmtFinSF1','BsmtUnfSF','TotalBsmtSF','BsmtFullBath','GarageCars','GarageArea'])

# %% [markdown]
# # Using Multi-Varied Linear Regression Model for prediction

# %%
from sklearn.linear_model import LinearRegression
X = df.drop(['SalePrice'],axis='columns')
y = df.SalePrice

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the house prices and for Test dataset and Add it to a new column in the dataset

# %%
bf['SalePrice_p'] = model.predict(bf)
bf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 bf['SalePrice_p'] = model.predict(bf)
#       2 bf
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
from sklearn.linear_model import Ridge
rg = Ridge(alpha=50, max_iter=100,tol=0.1)
rg.fit(X,y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
rg.score(X,y)
# Out:
# 0.8299474770823259

# %%
data = pd.read_csv('sample_submission[1].csv')
data
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
bf['salePrice'] = data.SalePrice

# %%
bf
# Out:
#       LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0            80.0    11622            5       1961          1961         0.0
# 1            81.0    14267            6       1958          1958       108.0
# 2            74.0    13830            5       1997          1998         0.0
# 3            78.0     9978            6       1998          1998        20.0
# 4            43.0     5005            8       1992          1992         0.0
# ...           ...      ...          ...        ...           ...         ...
# 1454         21.0     1936            4       1970          1970         0.0
# 1455         21.0     1894            4       1970          1970         0.0
# 1456        160.0    20000            5       1960          1996         0.0
# 1457         62.0    10441            5       1992          1992         0.0
# 1458         74.0     9627            7       1993          1994        94.0
#
# ...

# %%
rg.score(bf.drop(['salePrice'],axis=1),bf.salePrice)
# Out:
# -17.221615359715667

# %%
model.score(bf.drop(['salePrice'],axis=1),bf.salePrice)
# Out:
# -17.516761399342773

# %%
from sklearn.linear_model import Lasso
lg = Lasso(alpha=50, max_iter=100,tol=0.1)
lg.fit(X,y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lg.score(bf.drop(['salePrice'],axis=1),bf.salePrice)
# Out:
# -18.218515138902465

# %%
lg.s
